# %%
s = []
L = ['a', 'b', 'c' , 'd'] #set of star actors in 10 first result of search engine
for i in range(0 , len(L)) :
    for j in range(i+1,len(L)) :
        s.append(list((L[i],L[j]))) #make a nested list with all possible dual combination

# %%
s
# Out:
# [['a', 'b'], ['a', 'c'], ['a', 'd'], ['b', 'c'], ['b', 'd'], ['c', 'd']]

# %%
m1 = ['a', 'c', 'f', 'g']
m2 = ['j' , 'a', 'b' , 'd']
counter = 0
for i in s :
    print(all(elem in m2 for elem in i ))
# Out:
# True
# False
# True
# False
# True
# False

# %%
edge = []
counter = 0
for i in s : #for each dual combination
    for j in range(len(df.index)): # search in the whole dataset
        if(all(elem in df.iloc[j]["starring"]  for elem in i )) : #if both elements of the combination was in the document
            counter = counter + 1
            if (counter == 2 ): # we want them to be together in at least 2 movies 
                edge.append(tuple(i))
                break

# %%
edge = []
for i in s :
    edge.append(tuple(i))
edge
# Out:
# [('a', 'b'), ('a', 'c'), ('a', 'd'), ('b', 'c'), ('b', 'd'), ('c', 'd')]

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()
G.add_nodes_from(L)
G.add_edges_from(edge)
nx.draw(G, with_labels = 1)
plt.savefig("path_graph1.png")
plt.show()
